# %%
import matplotlib.pyplot as plt

# %%
#n_train = 200  # number of training points
#n_test = 100
x = [1, 2, 3, 4]
#LOF
ROC1_train = [1.0, 0.9989,0.8536,0.6647]
ROC1_test = [1.0, 1.0,0.9856,0.6544]
ACC1_train = [0.91, 0.95,0.92,0.84]
ACC1_test = [0.92, 0.93,0.91,0.83]
#KNN
ROC2_train = [1.0, 0.9979,0.85,0.9745]
ROC2_test = [1.0, 1.0,0.9956,1.0]
ACC2_train = [0.91, 0.95,0.94,0.9]
ACC2_test = [0.85, 0.94,0.95,0.91]
#iForest
ROC3_train = [1.0, 0.9953,0.8731,0.9572]
ROC3_test = [1.0, 0.9958,0.9889,0.9981]
ACC3_train = [0.91, 0.95,0.92,0.88]
ACC3_test = [0.84, 0.9,0.91,0.95]
#EIF(Threshold=0.5,0.5,0.46,0.46)
ROC4_train = [0.9773, 0.9368,0.6917,0.8531]
ROC4_test = [0.955, 0.97,0.8889,0.8375]
ACC4_train = [0.9596, 0.9789,0.885,0.915]
ACC4_test = [0.92, 0.96,0.88,0.89]
#DIF(threshold=0.32,0.32,0.32,0.28)
ROC5_train = [0.9773, 0.9368,0.6806,0.6688]
ROC5_test = [0.9596, 0.9789,0.9111,0.7438]
ACC5_train = [1.0, 0.99,0.955,0.905]
ACC5_test = [1.0, 1.0,0.98,0.98]

# %%
labels = ['0.01', '0.05', '0.1', '0.2']

plt.plot(x, ROC1_train,label='LOF')
plt.plot(x, ROC2_train,label='KNN')
plt.plot(x, ROC3_train,label='iForest')
plt.plot(x, ROC4_train,label='EIF')
plt.plot(x, ROC5_train,label='DIF')
plt.xticks(x, labels)
plt.margins(0.2)
plt.title("ROC with Training Data by Outlier")
plt.legend(loc="upper right")
plt.show()


plt.plot(x, ROC1_test,label='LOF')
plt.plot(x, ROC2_test,label='KNN')
plt.plot(x, ROC3_test,label='iForest')
plt.plot(x, ROC4_test,label='EIF')
plt.plot(x, ROC5_test,label='DIF')
plt.xticks(x, labels)
plt.margins(0.2)
plt.title("ROC with Testing Data by Outlier")
plt.legend(loc="upper right")
plt.show()


plt.plot(x, ACC1_train,label='LOF')
plt.plot(x, ACC2_train,label='KNN')
plt.plot(x, ACC3_train,label='iForest')
plt.plot(x, ACC4_train,label='EIF')
plt.plot(x, ACC5_train,label='DIF')
plt.xticks(x, labels)
plt.margins(0.2)
plt.title("Accuracy with Training Data by Outlier")
plt.legend(loc="upper right")
plt.show()


plt.plot(x, ACC1_test,label='LOF')
plt.plot(x, ACC2_test,label='KNN')
plt.plot(x, ACC3_test,label='iForest')
plt.plot(x, ACC4_test,label='EIF')
plt.plot(x, ACC5_test,label='DIF')
plt.xticks(x, labels)
plt.margins(0.2)
plt.title("Accuracy with Testing Data by Outlier")
plt.legend(loc="upper right")
plt.show()

# %%
#==============================================================
#outlier 10%
x = [1, 2, 3]
labels = ['300', '1500', '3000']
labels = ['Small', 'Medium', 'Large']
#LOF
ROC1_train = [0.8536,0.5886,0.5422]
ROC1_test = [0.9856,0.5309,0.5274]
ACC1_train = [0.92,0.84,0.836]
ACC1_test = [0.91,0.848,0.845]
#KNN
ROC2_train = [0.85,0.9991,0.9967]
ROC2_test = [0.9956,0.9856,0.992]
ACC2_train = [0.949,0.994,0.994]
ACC2_test = [0.95,0.994,0.992]
#iForest
ROC3_train = [0.8731,0.9978,0.9939]
ROC3_test = [0.9889,0.9854,0.9907]
ACC3_train = [0.92,0.988,0.986]
ACC3_test = [0.91,0.986,0.987]
#EIF(Threshold=0.46,0.48,0.48)
ROC4_train = [0.6917,0.9717,0.9192]
ROC4_test = [0.8889,0.9533,0.9233]
ACC4_train = [0.885,0.973,0.9705]
ACC4_test = [0.88,0.964,0.974]
#DIF(threshold=0.32,0.30,0.28)
ROC5_train = [0.6806,0.9411,0.9058]
ROC5_test = [0.9111,0.9411,0.9106]
ACC5_train = [0.955,0.991,0.9905]
ACC5_test = [0.98,0.988,0.989]

# %%
plt.plot(x, ROC1_train,label='LOF')
plt.plot(x, ROC2_train,label='KNN')
plt.plot(x, ROC3_train,label='iForest')
plt.plot(x, ROC4_train,label='EIF')
plt.plot(x, ROC5_train,label='DIF')
plt.xticks(x, labels)
plt.margins(0.2)
plt.title("ROC with Training Data by Data Size")
plt.legend(loc="upper right")
plt.show()


plt.plot(x, ROC1_test,label='LOF')
plt.plot(x, ROC2_test,label='KNN')
plt.plot(x, ROC3_test,label='iForest')
plt.plot(x, ROC4_test,label='EIF')
plt.plot(x, ROC5_test,label='DIF')
plt.xticks(x, labels)
plt.margins(0.2)
plt.title("ROC with Testing Data by Data Size")
plt.legend(loc="upper right")
plt.show()


plt.plot(x, ACC1_train,label='LOF')
plt.plot(x, ACC2_train,label='KNN')
plt.plot(x, ACC3_train,label='iForest')
plt.plot(x, ACC4_train,label='EIF')
plt.plot(x, ACC5_train,label='DIF')
plt.xticks(x, labels)
plt.margins(0.2)
plt.title("Accuracy with Training Data by Data Size")
plt.legend(loc="upper right")
plt.show()


plt.plot(x, ACC1_test,label='LOF')
plt.plot(x, ACC2_test,label='KNN')
plt.plot(x, ACC3_test,label='iForest')
plt.plot(x, ACC4_test,label='EIF')
plt.plot(x, ACC5_test,label='DIF')
plt.xticks(x, labels)
plt.margins(0.2)
plt.title("Accuracy with Testing Data by Data Size")
plt.legend(loc="upper right")
plt.show()
